# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Kayla\Downloads\amazon-orders.csv')
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    NaN    your_email@gmail.com      04/01/19
# 1                    NaN    your_email@gmail.com      04/01/19
# 2                    NaN    your_email@gmail.com      04/01/19
# 3                    NaN    your_email@gmail.com      04/05/19
# 4                    NaN    your_email@gmail.com      04/07/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        NaN
# ...

# %%
df = df.fillna(0)
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# 1                    0.0    your_email@gmail.com      04/01/19
# 2                    0.0    your_email@gmail.com      04/01/19
# 3                    0.0    your_email@gmail.com      04/05/19
# 4                    0.0    your_email@gmail.com      04/07/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        0.0
# ...

# %%
df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
df.head()
# Out:
# C:\Users\Kayla\AppData\Local\Temp\ipykernel_16312\2463331391.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# 1                    0.0    your_email@gmail.com      04/01/19
# ...

# %%
df["Total Charged"].sum()
# Out:
# 1777.7300000000002

# %%
df["Total Charged"].mean()
# Out:
# 30.131016949152546

# %%
df["Total Charged"].median()
# Out:
# 15.95

# %%
df["Total Charged"].max()
# Out:
# 210.99

# %%
df["Total Charged"].min()
# Out:
# 1.04

# %%
df["Total Charged"].std()
# Out:
# 36.42273246651456

# %%
df.plot.bar(x= 'Order Date', y='Total Charged', rot=90, figsize=(20,10))
# Out:
# <Axes: xlabel='Order Date'>

# %%
daily_orders = df.groupby("Order Date").sum()["Total Charged"]
daily_orders.head()
# Out:
# C:\Users\Kayla\AppData\Local\Temp\ipykernel_16312\3811466268.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   daily_orders = df.groupby("Order Date").sum()["Total Charged"]
# Order Date
# 04/01/19     63.91
# 04/04/19    156.12
# 04/05/19     27.64
# 04/07/19     40.63
# 04/08/19     44.99
# Name: Total Charged, dtype: float64

# %%
daily_orders.plot.bar(figsize=(20,10))
# Out:
# <Axes: xlabel='Order Date'>

# %%
import matplotlib.pyplot as plt

df = pd.DataFrame([63.91, 156.12, 27.64, 40.63, 44.99], index=["4/1/19", "4/4/19", "4/5/19", "4/7/19", "4/8/19"] )

df.plot(kind='pie', subplots=True)

plt.show()

# %%
df = pd.read_csv(r'C:\Users\Kayla\Downloads\amazon-orders.csv')
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    NaN    your_email@gmail.com      04/01/19
# 1                    NaN    your_email@gmail.com      04/01/19
# 2                    NaN    your_email@gmail.com      04/01/19
# 3                    NaN    your_email@gmail.com      04/05/19
# 4                    NaN    your_email@gmail.com      04/07/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        NaN
# ...

# %%
df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
df.head()
# Out:
# C:\Users\Kayla\AppData\Local\Temp\ipykernel_16312\148570183.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    NaN    your_email@gmail.com      04/01/19
# 1                    NaN    your_email@gmail.com      04/01/19
# ...

# %%
taxes = df.groupby("Order Date").sum()["Tax Charged"]
taxes.head()
# Out:
# C:\Users\Kayla\AppData\Local\Temp\ipykernel_16312\188918096.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   taxes = df.groupby("Order Date").sum()["Tax Charged"]
# Order Date
# 04/01/19    1.93
# 04/04/19    8.14
# 04/05/19    0.66
# 04/07/19    1.65
# 04/08/19    0.00
# Name: Tax Charged, dtype: float64

# %%
import matplotlib.pyplot as plt

df = pd.DataFrame([1.93, 8.14, 0.66, 1.65, 0.00], index=["4/1/19", "4/4/19", "4/5/19", "4/7/19", "4/8/19"] )

df.plot(kind='pie', subplots=True)

plt.show()
